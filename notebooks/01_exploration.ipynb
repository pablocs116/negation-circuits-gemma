# %%
import os
from huggingface_hub import login
login(token=os.environ.get("HF_TOKEN"))
print("Auth OK")
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# Auth OK

# %%
import torch
from circuit_tracer import attribute, Graph, ReplacementModel

device = "mps" if torch.backends.mps.is_available() else "cpu"
print(f"Device: {device}")
# Out:
# Device: mps

# %%
model = ReplacementModel.from_pretrained(
    "google/gemma-2-2b",
    transcoder_set="gemma",
    device=device,
    dtype=torch.float16,
)
tokenizer = model.tokenizer
print("Model loaded")
# Out:
# Fetching 26 files:   0%|          | 0/26 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
prompts = [
    "The capital of France is Paris. The capital of Germany is NOT Paris, it is",
    "Water is NOT a solid at room temperature, it is",
    "The sun does NOT orbit the Earth, the Earth orbits the",
    "Shakespeare was NOT born in London, he was born in",
    "Python is NOT a compiled language, it is a",
]

for p in prompts:
    tokens = tokenizer.encode(p)
    print(f"{len(tokens):3d} tokens | {p[:60]}...")
# Out:
#  18 tokens | The capital of France is Paris. The capital of Germany is NO...
#  12 tokens | Water is NOT a solid at room temperature, it is...
#  13 tokens | The sun does NOT orbit the Earth, the Earth orbits the...
#  12 tokens | Shakespeare was NOT born in London, he was born in...
#  11 tokens | Python is NOT a compiled language, it is a...

# %%
prompt = prompts[0]
graph = attribute(
    prompt=prompt,
    model=model,
    verbose=True,
)
print(f"Graph nodes: {len(graph.nodes)}")
print(f"Graph edges: {len(graph.edges)}")
# Out:
# Phase 0: Precomputing activations and vectors
# ---------------------------------------------------------------------------
# SafetensorError                           Traceback (most recent call last)
# Cell In[5], line 2
#       1 prompt = prompts[0]
# ----> 2 graph = attribute(
#       3     prompt=prompt,
#       4     model=model,
#       5     verbose=True,
#
# File ~/Projects/negation-circuits-gemma/.venv/lib/python3.14/site-packages/circuit_tracer/attribution/attribute.py:81, in attribute(prompt, model, attribution_targets, max_n_logits, desired_logit_prob, batch_size, max_feature_nodes, offload, verbose, update_interval)
#      78 else:
#      79     from .attribute_transformerlens import attribute as attribute_transformerlens
# ---> 81     return attribute_transformerlens(
#      82         prompt=prompt,
#      83         model=model,  # type: ignore[arg-type]
#      84         attribution_targets=attribution_targets,
#      85         max_n_logits=max_n_logits,
#      86         desired_logit_prob=desired_logit_prob,
#      87         batch_size=batch_size,
#      88         max_feature_nodes=max_feature_nodes,
#      89         offload=offload,
#      90         verbose=verbose,
#      91         update_interval=update_interval,
#      92     )
#
# File ~/Projects/negation-circuits-gemma/.venv/lib/python3.14/site-packages/circuit_tracer/attribution/attribute_transformerlens.py:97, in attribute(prompt, model, attribution_targets, max_n_logits, desired_logit_prob, batch_size, max_feature_nodes, offload, verbose, update_interval)
#      95 offload_handles = []
#      96 try:
# ---> 97     return _run_attribution(
#      98         model=model,
#      99         prompt=prompt,
#     100         attribution_targets=attribution_targets,
#     101         max_n_logits=max_n_logits,
#     102         desired_logit_prob=desired_logit_prob,
#     103         batch_size=batch_size,
#     104         max_feature_nodes=max_feature_nodes,
#     105         offload=offload,
#     106         verbose=verbose,
#     107         offload_handles=offload_handles,
#     108         update_interval=update_interval,
#     109         logger=logger,
#     110     )
#     111 finally:
#     112     for reload_handle in offload_handles:
#
# File ~/Projects/negation-circuits-gemma/.venv/lib/python3.14/site-packages/circuit_tracer/attribution/attribute_transformerlens.py:139, in _run_attribution(model, prompt, attribution_targets, max_n_logits, desired_logit_prob, batch_size, max_feature_nodes, offload, verbose, offload_handles, logger, update_interval)
#     136 phase_start = time.time()
#     137 input_ids = model.ensure_tokenized(prompt)
# --> 139 ctx = model.setup_attribution(input_ids)
#     140 activation_matrix = ctx.activation_matrix
#     142 logger.info(f"Precomputation completed in {time.time() - phase_start:.2f}s")
#
# File ~/Projects/negation-circuits-gemma/.venv/lib/python3.14/site-packages/torch/utils/_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File ~/Projects/negation-circuits-gemma/.venv/lib/python3.14/site-packages/circuit_tracer/replacement_model/replacement_model_transformerlens.py:454, in TransformerLensReplacementModel.setup_attribution(self, inputs)
#     451 mlp_in_cache = torch.cat(list(mlp_in_cache.values()), dim=0)
#     452 mlp_out_cache = torch.cat(list(mlp_out_cache.values()), dim=0)
# --> 454 attribution_data = self.transcoders.compute_attribution_components(
#     455     mlp_in_cache, self.zero_positions
#     456 )
#     458 # Compute error vectors
#     459 error_vectors = mlp_out_cache - attribution_data["reconstruction"]
#
# File ~/Projects/negation-circuits-gemma/.venv/lib/python3.14/site-packages/circuit_tracer/transcoder/single_layer_transcoder.py:369, in TranscoderSet.compute_attribution_components(self, mlp_inputs, zero_positions)
#     365 for layer, transcoder in enumerate[SingleLayerTranscoder](self.transcoders):  # type: ignore
#     366     sparse_acts, active_encoders = transcoder.encode_sparse(
#     367         mlp_inputs[layer], zero_positions=zero_positions
#     368     )
# --> 369     reconstruction[layer], active_decoders = transcoder.decode_sparse(
#     370         sparse_acts, mlp_inputs[layer]
#     371     )
#     372     encoder_vectors.append(active_encoders)
#     373     decoder_vectors.append(active_decoders)
#
# File ~/Projects/negation-circuits-gemma/.venv/lib/python3.14/site-packages/circuit_tracer/transcoder/single_layer_transcoder.py:185, in SingleLayerTranscoder.decode_sparse(self, sparse_acts, input_acts)
#     182 values = sparse_acts.values()
#     184 # Get decoder vectors for active features only
# --> 185 W_dec = self._get_decoder_vectors(feat_idx.cpu())
#     186 scaled_decoders = W_dec * values[:, None]
#     188 # Reconstruct using index_add
#
# File ~/Projects/negation-circuits-gemma/.venv/lib/python3.14/site-packages/circuit_tracer/transcoder/single_layer_transcoder.py:117, in SingleLayerTranscoder._get_decoder_vectors(self, feat_ids)
#     115 if isinstance(to_read, torch.Tensor):
#     116     to_read = to_read.cpu()
# --> 117 with safe_open(self.transcoder_path, framework="pt", device=str(self.device)) as f:
#     118     return f.get_slice("W_dec")[to_read].to(self.dtype)
#
# SafetensorError: device mps:0 is invalid
