# %%
# !pip install circuit-tracer
# !pip install --upgrade huggingface_hub transformers
# Out:
# Requirement already satisfied: circuit-tracer in /usr/local/lib/python3.12/dist-packages (0.5.0)
# Requirement already satisfied: einops>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from circuit-tracer) (0.8.2)
# Collecting huggingface-hub<1.0.0 (from circuit-tracer)
#   Using cached huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: nnsight>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from circuit-tracer) (0.7.0)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.12/dist-packages (from circuit-tracer) (2.0.2)
# Requirement already satisfied: pydantic>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from circuit-tracer) (2.12.3)
# Requirement already satisfied: safetensors>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from circuit-tracer) (0.7.0)
# Requirement already satisfied: tokenizers>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from circuit-tracer) (0.22.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from circuit-tracer) (2.11.0+cpu)
# Requirement already satisfied: tqdm>=4.60.0 in /usr/local/lib/python3.12/dist-packages (from circuit-tracer) (4.67.3)
# Requirement already satisfied: transformer-lens>=2.16.0 in /usr/local/lib/python3.12/dist-packages (from circuit-tracer) (3.2.1)
# Collecting transformers<=4.57.3,>=4.56.0 (from circuit-tracer)
#   Using cached transformers-4.57.3-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0->circuit-tracer) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0->circuit-tracer) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0->circuit-tracer) (1.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0->circuit-tracer) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0->circuit-tracer) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0->circuit-tracer) (2.32.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0->circuit-tracer) (4.15.0)
# Requirement already satisfied: astor in /usr/local/lib/python3.12/dist-packages (from nnsight>=0.6.0->circuit-tracer) (0.8.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from nnsight>=0.6.0->circuit-tracer) (3.1.2)
# Requirement already satisfied: httpx in /usr/local/lib/python3.12/dist-packages (from nnsight>=0.6.0->circuit-tracer) (0.28.1)
# Requirement already satisfied: python-socketio[client] in /usr/local/lib/python3.12/dist-packages (from nnsight>=0.6.0->circuit-tracer) (5.16.2)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (from nnsight>=0.6.0->circuit-tracer) (1.13.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.12/dist-packages (from nnsight>=0.6.0->circuit-tracer) (0.10.2)
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (from nnsight>=0.6.0->circuit-tracer) (7.34.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from nnsight>=0.6.0->circuit-tracer) (13.9.4)
# Requirement already satisfied: zstandard in /usr/local/lib/python3.12/dist-packages (from nnsight>=0.6.0->circuit-tracer) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->circuit-tracer) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->circuit-tracer) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->circuit-tracer) (0.4.2)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->circuit-tracer) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->circuit-tracer) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->circuit-tracer) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->circuit-tracer) (3.1.6)
# Requirement already satisfied: beartype>=0.14.1 in /usr/local/lib/python3.12/dist-packages (from transformer-lens>=2.16.0->circuit-tracer) (0.22.9)
# Requirement already satisfied: better-abc>=0.0.3 in /usr/local/lib/python3.12/dist-packages (from transformer-lens>=2.16.0->circuit-tracer) (0.0.3)
# Requirement already satisfied: datasets>=2.7.1 in /usr/local/lib/python3.12/dist-packages (from transformer-lens>=2.16.0->circuit-tracer) (4.0.0)
# Requirement already satisfied: fancy-einsum>=0.0.3 in /usr/local/lib/python3.12/dist-packages (from transformer-lens>=2.16.0->circuit-tracer) (0.0.3)
# Requirement already satisfied: jaxtyping>=0.2.11 in /usr/local/lib/python3.12/dist-packages (from transformer-lens>=2.16.0->circuit-tracer) (0.3.10)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.12/dist-packages (from transformer-lens>=2.16.0->circuit-tracer) (2.2.2)
# Requirement already satisfied: protobuf>=3.20.0 in /usr/local/lib/python3.12/dist-packages (from transformer-lens>=2.16.0->circuit-tracer) (5.29.6)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from transformer-lens>=2.16.0->circuit-tracer) (0.2.1)
# Requirement already satisfied: transformers-stream-generator<0.1,>=0.0.5 in /usr/local/lib/python3.12/dist-packages (from transformer-lens>=2.16.0->circuit-tracer) (0.0.5)
# Requirement already satisfied: typeguard<5,>=4.2 in /usr/local/lib/python3.12/dist-packages (from transformer-lens>=2.16.0->circuit-tracer) (4.5.2)
# Requirement already satisfied: wandb>=0.13.5 in /usr/local/lib/python3.12/dist-packages (from transformer-lens>=2.16.0->circuit-tracer) (0.27.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<=4.57.3,>=4.56.0->circuit-tracer) (2025.11.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate->nnsight>=0.6.0->circuit-tracer) (5.9.5)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.7.1->transformer-lens>=2.16.0->circuit-tracer) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.7.1->transformer-lens>=2.16.0->circuit-tracer) (0.3.8)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=2.7.1->transformer-lens>=2.16.0->circuit-tracer) (3.7.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.7.1->transformer-lens>=2.16.0->circuit-tracer) (0.70.16)
# Requirement already satisfied: wadler-lindig>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from jaxtyping>=0.2.11->transformer-lens>=2.16.0->circuit-tracer) (0.1.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.5->transformer-lens>=2.16.0->circuit-tracer) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.5->transformer-lens>=2.16.0->circuit-tracer) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.5->transformer-lens>=2.16.0->circuit-tracer) (2026.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<1.0.0->circuit-tracer) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<1.0.0->circuit-tracer) (3.15)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<1.0.0->circuit-tracer) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<1.0.0->circuit-tracer) (2026.5.20)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->nnsight>=0.6.0->circuit-tracer) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->nnsight>=0.6.0->circuit-tracer) (2.20.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->circuit-tracer) (1.3.0)
# Requirement already satisfied: click>=8.2.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.13.5->transformer-lens>=2.16.0->circuit-tracer) (8.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.13.5->transformer-lens>=2.16.0->circuit-tracer) (3.1.50)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb>=0.13.5->transformer-lens>=2.16.0->circuit-tracer) (4.9.6)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.13.5->transformer-lens>=2.16.0->circuit-tracer) (2.60.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx->nnsight>=0.6.0->circuit-tracer) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx->nnsight>=0.6.0->circuit-tracer) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx->nnsight>=0.6.0->circuit-tracer) (0.16.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython->nnsight>=0.6.0->circuit-tracer) (0.20.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython->nnsight>=0.6.0->circuit-tracer) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython->nnsight>=0.6.0->circuit-tracer) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from ipython->nnsight>=0.6.0->circuit-tracer) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython->nnsight>=0.6.0->circuit-tracer) (3.0.52)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython->nnsight>=0.6.0->circuit-tracer) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython->nnsight>=0.6.0->circuit-tracer) (0.2.2)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython->nnsight>=0.6.0->circuit-tracer) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->circuit-tracer) (3.0.3)
# Requirement already satisfied: bidict>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from python-socketio[client]->nnsight>=0.6.0->circuit-tracer) (0.23.1)
# Requirement already satisfied: python-engineio>=4.13.2 in /usr/local/lib/python3.12/dist-packages (from python-socketio[client]->nnsight>=0.6.0->circuit-tracer) (4.13.2)
# Requirement already satisfied: websocket-client>=0.54.0 in /usr/local/lib/python3.12/dist-packages (from python-socketio[client]->nnsight>=0.6.0->circuit-tracer) (1.9.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer-lens>=2.16.0->circuit-tracer) (3.13.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer-lens>=2.16.0->circuit-tracer) (4.0.12)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython->nnsight>=0.6.0->circuit-tracer) (0.8.7)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->nnsight>=0.6.0->circuit-tracer) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython->nnsight>=0.6.0->circuit-tracer) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->nnsight>=0.6.0->circuit-tracer) (0.7.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->transformer-lens>=2.16.0->circuit-tracer) (1.17.0)
# Requirement already satisfied: simple-websocket>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from python-engineio>=4.13.2->python-socketio[client]->nnsight>=0.6.0->circuit-tracer) (1.1.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer-lens>=2.16.0->circuit-tracer) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer-lens>=2.16.0->circuit-tracer) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer-lens>=2.16.0->circuit-tracer) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer-lens>=2.16.0->circuit-tracer) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer-lens>=2.16.0->circuit-tracer) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer-lens>=2.16.0->circuit-tracer) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.7.1->transformer-lens>=2.16.0->circuit-tracer) (1.24.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer-lens>=2.16.0->circuit-tracer) (5.0.3)
# Requirement already satisfied: wsproto in /usr/local/lib/python3.12/dist-packages (from simple-websocket>=0.10.0->python-engineio>=4.13.2->python-socketio[client]->nnsight>=0.6.0->circuit-tracer) (1.3.2)
# Using cached huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
# Using cached transformers-4.57.3-py3-none-any.whl (12.0 MB)
# Installing collected packages: huggingface-hub, transformers
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.17.0
#     Uninstalling huggingface_hub-1.17.0:
#       Successfully uninstalled huggingface_hub-1.17.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.9.0
#     Uninstalling transformers-5.9.0:
#       Successfully uninstalled transformers-5.9.0
# Successfully installed huggingface-hub-0.36.2 transformers-4.57.3
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (0.36.2)
# Collecting huggingface_hub
#   Using cached huggingface_hub-1.17.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.3)
# Collecting transformers
#   Using cached transformers-5.9.0-py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: click>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (8.4.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.67.3)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.15)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface_hub) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface_hub) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface_hub) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub) (0.1.2)
# Using cached huggingface_hub-1.17.0-py3-none-any.whl (671 kB)
# Using cached transformers-5.9.0-py3-none-any.whl (10.8 MB)
# Installing collected packages: huggingface_hub, transformers
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface_hub 0.36.2
#     Uninstalling huggingface_hub-0.36.2:
#       Successfully uninstalled huggingface_hub-0.36.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.3
#     Uninstalling transformers-4.57.3:
#       Successfully uninstalled transformers-4.57.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# circuit-tracer 0.5.0 requires huggingface-hub<1.0.0, but you have huggingface-hub 1.17.0 which is incompatible.
# circuit-tracer 0.5.0 requires transformers<=4.57.3,>=4.56.0, but you have transformers 5.9.0 which is incompatible.
# Successfully installed huggingface_hub-1.17.0 transformers-5.9.0

# %%
import os
from huggingface_hub import login
login(token=os.environ.get("HF_TOKEN"))
print("Auth OK")
# Out:
# Auth OK

# %%
import torch
from circuit_tracer import attribute, Graph, ReplacementModel

device = "mps" if torch.backends.cuda.is_available() else "cpu"
print(f"Device: {device}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_5708/2691857972.py in <cell line: 0>()
#       1 import torch
# ----> 2 from circuit_tracer import attribute, Graph, ReplacementModel
#       3
#       4 device = "mps" if torch.backends.mps.is_available() else "cpu"
#       5 print(f"Device: {device}")
#
# /usr/local/lib/python3.12/dist-packages/circuit_tracer/__init__.py in __getattr__(name)
#      30     if name in _lazy_imports:
#      31         module_name, attr_name = _lazy_imports[name]
# ---> 32         module = __import__(module_name, fromlist=[attr_name])
#      33         return getattr(module, attr_name)
#      34     else:
#
# /usr/local/lib/python3.12/dist-packages/circuit_tracer/replacement_model/__init__.py in <module>
#       3 """
#       4
# ----> 5 from .replacement_model import ReplacementModel
#       6
#       7 __all__ = [
#
# /usr/local/lib/python3.12/dist-packages/circuit_tracer/replacement_model/replacement_model.py in <module>
#      10 from circuit_tracer.transcoder.cross_layer_transcoder import CrossLayerTranscoder
#      11 from circuit_tracer.utils import get_default_device
# ---> 12 from circuit_tracer.utils.hf_utils import load_transcoder_from_hub
#      13
#      14 Backend = Literal["nnsight", "transformerlens"]
#
# /usr/local/lib/python3.12/dist-packages/circuit_tracer/utils/hf_utils.py in <module>
#      11 import yaml
#      12 from huggingface_hub import get_token, hf_api, hf_hub_download, snapshot_download
# ---> 13 from huggingface_hub.constants import HF_HUB_ENABLE_HF_TRANSFER
#      14 from huggingface_hub.utils.tqdm import tqdm as hf_tqdm
#      15 from tqdm.contrib.concurrent import thread_map
#
# ImportError: cannot import name 'HF_HUB_ENABLE_HF_TRANSFER' from 'huggingface_hub.constants' (/usr/local/lib/python3.12/dist-packages/huggingface_hub/constants.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
model = ReplacementModel.from_pretrained(
    "google/gemma-2-2b",
    transcoder_set="gemma",
    device=device,
    dtype=torch.float16,
)
tokenizer = model.tokenizer
print("Model loaded")

# %%
prompts = [
    "The capital of France is Paris. The capital of Germany is NOT Paris, it is",
    "Water is NOT a solid at room temperature, it is",
    "The sun does NOT orbit the Earth, the Earth orbits the",
    "Shakespeare was NOT born in London, he was born in",
    "Python is NOT a compiled language, it is a",
]

for p in prompts:
    tokens = tokenizer.encode(p)
    print(f"{len(tokens):3d} tokens | {p[:60]}...")

# %%
prompt = prompts[0]
graph = attribute(
    prompt=prompt,
    model=model,
    verbose=True,
)
print(f"Graph nodes: {len(graph.nodes)}")
print(f"Graph edges: {len(graph.edges)}")
